# %% [markdown]
# <a href="https://colab.research.google.com/github/k-a-s-s-0-9/better-cry-sense/blob/main/Better_cry_sense.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Setup and Installation
import os

# 1. Clone the repository
REPO_URL = "https://github.com/k-a-s-s-0-9/better-cry-sense.git"
REPO_DIR = "better-cry-sense"

if not os.path.exists(REPO_DIR):
    print(f"Cloning {REPO_URL}...")
    # !git clone {REPO_URL}
else:
    print("Repository already exists. Pulling latest changes...")
    # %cd {REPO_DIR}
    # !git pull
    # %cd ..

# 2. Install dependencies
# If you have a requirements.txt, we use that.
# Otherwise, common DS/CS libraries are pre-installed in Colab.
requirements_path = os.path.join(REPO_DIR, "requirements.txt")
if os.path.exists(requirements_path):
    print("Installing requirements...")
    # !pip install -r {requirements_path}

# 3. Add to system path so you can import your modules
import sys
sys.path.append(os.path.abspath(REPO_DIR))

print("\nSetup complete. You are ready to run the project.")
# Out:
# Cloning https://github.com/k-a-s-s-0-9/better-cry-sense.git...
# Cloning into 'better-cry-sense'...
# remote: Enumerating objects: 7955, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (46/46), done.
# remote: Total 7955 (delta 22), reused 0 (delta 0), pack-reused 7909 (from 2)
# Receiving objects: 100% (7955/7955), 146.71 MiB | 19.04 MiB/s, done.
# Resolving deltas: 100% (207/207), done.
# Updating files: 100% (5217/5217), done.
#
# Setup complete. You are ready to run the project.

# %%
# @title Project Configuration { run: "auto" }
# Define any constants or paths here
MODEL_PATH = "better-cry-sense/models/" #@param {type:"string"}
USE_GPU = True #@param {type:"boolean"}

if USE_GPU:
    import torch
    device = "cuda" if torch.cuda.is_available() else "cpu"
    print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
import sys
import os

# 1. Fix the naming convention for Python imports
if os.path.exists('/content/better-cry-sense'):
    # !mv /content/better-cry-sense /content/better_cry_sense

# 2. Add the root to the system path
repo_path = '/content/better_cry_sense'
if repo_path not in sys.path:
    sys.path.append(repo_path)

print("Environment Prepared.")
# Out:
# Environment Prepared.

# %%
import sys
import os

# !ls /content/better_cry_sense
# !ls /content/better_cry_sense/model
#!ls /content/better_cry_sense/data/processed/belly_pain/mfcc works
# Out:
# data  model  Readme.md	test-results  tests
# data_pipeline.py  model_architecture.py  train.py

# %%
# 1. Enter the logic directory
# This allows 'train.py' to find 'data_pipeline' and 'model_architecture' locally
# %cd /content/better_cry_sense/model

# 2. Start the Training
# This will trigger:
# - GPU memory growth setup
# - Manifest building with class weights (to handle the 382 vs 50 imbalance)
# - 50 Epochs of training with EarlyStopping and ModelCheckpoints
# !python train.py
# Out:
# /content/better_cry_sense/model
# 2026-05-03 01:19:12.032409: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 🚀 Initiating Better Cry Sense Training Sequence...
# ✅ GPU Memory Growth Enabled: 1 GPU(s) found.
# DEBUG: Scanning directories in /content/better_cry_sense/data/processed...
# 📊 Pipeline Built: 1317 Train | 312 Val | 405 Test
# ⚖️ Calculating Class Weights...
#    -> Class 0 Weight: 1.20
#    -> Class 1 Weight: 1.50
#    -> Class 2 Weight: 1.20
#    -> Class 3 Weight: 0.80
#    -> Class 4 Weight: 1.20
# 📦 Spinning up Data Generators (Batch Size: 32)...
# 🏗️ Constructing CRNN Architecture...
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...
